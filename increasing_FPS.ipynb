# %% [markdown]
# <a href="https://colab.research.google.com/github/avgCoderr/frames-/blob/main/increasing_FPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %matplotlib inline

# %%
import cv2
from matplotlib import pyplot as plt

# %%
i=1
k=1
while(i<110):
  
  image1 = cv2.imread("/content/gdrive/MyDrive/Colab Notebooks/datasets/increasing FPS/110 frames/1 (" + str(i) + ").jpg")
  image2 = cv2.imread("/content/gdrive/MyDrive/Colab Notebooks/datasets/increasing FPS/110 frames/1 (" + str(i+1) + ").jpg")

  new_image = cv2.addWeighted(image1, 0.5, image2, 0.5, 0)

  plt.imshow(new_image)
  plt.show()

  path = '/content/gdrive/MyDrive/Colab Notebooks/datasets/increasing FPS/new frames'

  # image 1
  filename = 'frame' + str(k) + '.jpg'
  cv2.imwrite(os.path.join(path , filename), image1)
  k = k + 1

  # average frame
  filename = 'frame' + str(k) + '.jpg'
  cv2.imwrite(os.path.join(path , filename), new_image)
  k = k + 1

  i = i + 1

# %%
# !rm -r data
